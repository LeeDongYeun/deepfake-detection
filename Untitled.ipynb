# %%
import sys 
import os
from os import rename, listdir
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
path = 'C://Users/LeeDongYeun/Desktop/오목눈이/fcft0/video/'

# %%
files = listdir(path)

# %%
files
# Out:
# ['head',
#  'head2',
#  'head3',
#  'sa1',
#  'sa2',
#  'si1178',
#  'si1808',
#  'si548',
#  'sx188',
#  'sx278',
#  'sx368',
#  'sx8',
#  'sx98']

# %%
for file in files:
    images = listdir(path + file)
    for name in images:
        abs_name = path+ file +'/' + name

        new_name = abs_name + '.png'
        rename(abs_name, new_name)
# Out:
# ['001', '002', '003', '004', '005', '006', '007', '008', '009', '010', '011', '012', '013', '014', '015', '016', '017', '018', '019', '020', '021', '022', '023', '024', '025', '026', '027', '028', '029', '030', '031', '032', '033', '034', '035', '036', '037', '038', '039', '040', '041', '042', '043', '044', '045', '046', '047', '048', '049', '050', '051', '052', '053', '054', '055', '056', '057', '058', '059', '060', '061', '062', '063', '064', '065', '066', '067', '068', '069', '070', '071', '072', '073', '074', '075', '076', '077', '078', '079', '080', '081', '082', '083', '084', '085', '086', '087', '088', '089', '090', '091', '092', '093', '094', '095', '096', '097', '098', '099', '100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '14
# ...

# %%
os.path.abspath(name)
# Out:
# 'C:\\Users\\LeeDongYeun\\Documents\\development\\deepfake-detection\\742'

# %%
p = 'C://Users/LeeDongYeun/Documents/development/deepfake-detection/images/'
to_p = 'C://Users/LeeDongYeun/Documents/development/deepfake-detection/resized_images/'

# %%
img_list = os.listdir(p)

# %%
for imgpath in img_list:
    img = cv2.imread(p + imgpath)
    img = cv2.resize(img, (256,256))
    cv2.imwrite(to_p + imgpath, img)

# %%
image.shape
# Out:
# (4808, 3846, 3)

# %%
img = cv2.resize(image, (256,256))

# %%
plt.imshow(img)

# %%
def split_into_frames(video_path, folder):
    if not os.path.isdir(folder):
        os.mkdir(folder)
    vidcap = cv2.VideoCapture(video_path)
    frame_num = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = vidcap.get(cv2.CAP_PROP_FPS)
    width = np.int32(vidcap.get(cv2.CAP_PROP_FRAME_WIDTH)) # float
    height = np.int32(vidcap.get(cv2.CAP_PROP_FRAME_HEIGHT))  # float
    imgs = []
    while True:
        success, image = vidcap.read()
        if success:
            imgs.append(image)
        else:
            break

    vidcap.release()
    if len(imgs) != frame_num:
        frame_num = len(imgs)
    for id, im in enumerate(imgs):
        im_name = '{:05d}.jpg'.format(id)
        cv2.imwrite(folder + '/' + im_name, im)
    print('Save original images to folder {}'.format(folder))

# %%
fakepath = 'C://Users/LeeDongYeun/Desktop/vidtimit/vidtimit/fake_videos/fake_videos/fake/'
realpath = 'C://Users/LeeDongYeun/Desktop/vidtimit/vidtimit/fake_videos/fake_videos/real/'

# %%
fakesplitpath = 'C://Users/LeeDongYeun/Desktop/vidtimit/vidtimit/fake_videos/fake_videos/uadfv/fake/'
realsplitpath = 'C://Users/LeeDongYeun/Desktop/vidtimit/vidtimit/fake_videos/fake_videos/uadfv/real/'

# %%
fakefile = listdir(fakepath)

# %%
fakefile
# Out:
# ['0000_fake.mp4',
#  '0001_fake.mp4',
#  '0002_fake.mp4',
#  '0003_fake.mp4',
#  '0004_fake.mp4',
#  '0005_fake.mp4',
#  '0006_fake.mp4',
#  '0007_fake.mp4',
#  '0008_fake.mp4',
#  '0009_fake.mp4',
#  '0010_fake.mp4',
#  '0011_fake.mp4',
#  '0012_fake.mp4',
#  '0013_fake.mp4',
#  '0014_fake.mp4',
#  '0015_fake.mp4',
#  '0016_fake.mp4',
#  '0017_fake.mp4',
#  '0018_fake.mp4',
#  '0019_fake.mp4',
#  '0020_fake.mp4',
#  '0021_fake.mp4',
#  '0022_fake.mp4',
#  '0023_fake.mp4',
#  '0024_fake.mp4',
#  '0025_fake.mp4',
#  '0026_fake.mp4',
#  '0027_fake.mp4',
#  '0028_fake.mp4',
#  '0029_fake.mp4',
#  '0030_fake.mp4',
#  '0031_fake.mp4',
#  '0032_fake.mp4',
#  '0033_fake.mp4',
#  '0034_fake.mp4',
#  '0035_fake.mp4',
#  '0036_fake.mp4',
#  '0037_fake.mp4',
#  '0038_fake.mp4',
#  '0039_fake.mp4',
#  '0040_fake.mp4',
#  '0041_fake.mp4',
#  '0042_fake.mp4',
#  '0043_fake.mp4',
#  '0044_fake.mp4',
#  '0045_fake.mp4',
#  '0046_fake.mp4',
#  '0047_fake.mp4',
#  '0048_fake.mp4']

# %%
for video in fakefile:
    split = video.split('.')[0]
    split = fakesplitpath + split
    split_into_frames(fakepath + video, split)
# Out:
# Save original images to folder C://Users/LeeDongYeun/Desktop/vidtimit/vidtimit/fake_videos/fake_videos/uadfv/fake/0000_fake
# Save original images to folder C://Users/LeeDongYeun/Desktop/vidtimit/vidtimit/fake_videos/fake_videos/uadfv/fake/0001_fake
# Save original images to folder C://Users/LeeDongYeun/Desktop/vidtimit/vidtimit/fake_videos/fake_videos/uadfv/fake/0002_fake
# Save original images to folder C://Users/LeeDongYeun/Desktop/vidtimit/vidtimit/fake_videos/fake_videos/uadfv/fake/0003_fake
# Save original images to folder C://Users/LeeDongYeun/Desktop/vidtimit/vidtimit/fake_videos/fake_videos/uadfv/fake/0004_fake
# Save original images to folder C://Users/LeeDongYeun/Desktop/vidtimit/vidtimit/fake_videos/fake_videos/uadfv/fake/0005_fake
# Save original images to folder C://Users/LeeDongYeun/Desktop/vidtimit/vidtimit/fake_videos/fake_videos/uadfv/fake/0006_fake
# ...

# %%
realfile = listdir(realpath)

# %%
for video in realfile:
    split = video.split('.')[0]
    split = realsplitpath + split
    split_into_frames(realpath + video, split)
# Out:
# Save original images to folder C://Users/LeeDongYeun/Desktop/vidtimit/vidtimit/fake_videos/fake_videos/uadfv/real/0000
# Save original images to folder C://Users/LeeDongYeun/Desktop/vidtimit/vidtimit/fake_videos/fake_videos/uadfv/real/0001
# Save original images to folder C://Users/LeeDongYeun/Desktop/vidtimit/vidtimit/fake_videos/fake_videos/uadfv/real/0002
# Save original images to folder C://Users/LeeDongYeun/Desktop/vidtimit/vidtimit/fake_videos/fake_videos/uadfv/real/0003
# Save original images to folder C://Users/LeeDongYeun/Desktop/vidtimit/vidtimit/fake_videos/fake_videos/uadfv/real/0004
# Save original images to folder C://Users/LeeDongYeun/Desktop/vidtimit/vidtimit/fake_videos/fake_videos/uadfv/real/0005
# Save original images to folder C://Users/LeeDongYeun/Desktop/vidtimit/vidtimit/fake_videos/fake_videos/uadfv/real/0006
# Save original images to folder C://Users/LeeDongYeun/Desktop/vidtimit/vidtimit/fake_videos/fake_videos/uadfv/real/0007
# ...
